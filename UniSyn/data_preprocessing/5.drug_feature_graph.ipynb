# %%
from rdkit import Chem
import numpy as np
import pandas as pd
import torch
import torch_geometric
from torch_geometric.data import Data
from dgllife.utils import *

# %%
def atom_to_feature_vector(atom):
    """
    Converts rdkit atom object to feature list of indices
    :param mol: rdkit atom object
    :return: list
    8 features are canonical, 2 features are from OGB
    """
    featurizer_funcs = ConcatFeaturizer([atom_type_one_hot,
                                         atom_degree_one_hot,
                                         atom_implicit_valence_one_hot,
                                         atom_formal_charge,
                                         atom_num_radical_electrons,
                                         atom_hybridization_one_hot,
                                         atom_is_aromatic,
                                         atom_total_num_H_one_hot,
                                         atom_is_in_ring,
                                         atom_chirality_type_one_hot,
                                         ])
    atom_feature = featurizer_funcs(atom)
    return atom_feature

# %%
def bond_to_feature_vector(bond):
    """
    Converts rdkit bond object to feature list of indices
    :param mol: rdkit bond object
    :return: list
    """
    featurizer_funcs = ConcatFeaturizer([bond_type_one_hot,
                                         # bond_is_conjugated,
                                         # bond_is_in_ring,
                                         # bond_stereo_one_hot,
                                         ])
    bond_feature = featurizer_funcs(bond)

    return bond_feature

# %%
def smiles2graph(mol):
    """
    Converts SMILES string or rdkit's mol object to graph Data object without remove salt
    :input: SMILES string (str)
    :return: graph object
    """

    if isinstance(mol, Chem.rdchem.Mol):
        pass
    else:
        mol = Chem.MolFromSmiles(mol)

    # atoms
    atom_features_list = []
    for atom in mol.GetAtoms():
        atom_features_list.append(atom_to_feature_vector(atom))
    x = np.array(atom_features_list, dtype=np.int64)

    # bonds
    num_bond_features = 4  # bond type, bond stereo, is_conjugated
    if len(mol.GetBonds()) > 0:  # mol has bonds
        edges_list = []
        edge_features_list = []
        for bond in mol.GetBonds():
            i = bond.GetBeginAtomIdx()
            j = bond.GetEndAtomIdx()

            edge_feature = bond_to_feature_vector(bond)

            # add edges in both directions
            edges_list.append((i, j))
            edge_features_list.append(edge_feature)
            edges_list.append((j, i))
            edge_features_list.append(edge_feature)

        # data.edge_index: Graph connectivity in COO format with shape [2, num_edges]
        edge_index = np.array(edges_list, dtype=np.int64).T

        # data.edge_attr: Edge feature matrix with shape [num_edges, num_edge_features]
        edge_attr = np.array(edge_features_list, dtype=np.int64)

    else:  # mol has no bonds
        edge_index = np.empty((2, 0), dtype=np.int64)
        edge_attr = np.empty((0, num_bond_features), dtype=np.int64)

    graph = Data(x=torch.tensor(x, dtype=torch.float),
                 edge_index=torch.tensor(edge_index, dtype=torch.long),
                 edge_attr=torch.tensor(edge_attr), dtype=torch.float)

    return graph

# %%
smiles = pd.read_csv("./Drug_smiles.csv")

# %%
smiles
# Out:
#       Unnamed: 0                          Drug  \
# 0              0               (+)-Bicuculline
# 1              1   (+)-PD 128907 hydrochloride
# 2              2                (+)-Usnic acid
# 3              3              (-)-Blebbistatin
# 4              4  (-)-Epigallocatechin gallate
# ...          ...                           ...
# 3118        3118                       IGF-OSI
# 3119        3119                      LSM-4270
# 3120        3120                SCHEMBL1557791
# 3121        3121                SCHEMBL1559365
# 3122        3122                SCHEMBL3313928
#
#                                                  SMILES
# 0     CN1CCC2=CC3=C(C=C2C1C4C5=C(C6=C(C=C5)OCO6)C(=O...
# 1                      CCCN1CCOC2C1COC3=C2C=C(C=C3)O.Cl
# 2     CC1=C(C(=C2C(=C1O)C3(C(=CC(=C(C3=O)C(=O)C)O)O2...
# 3          CC1=CC2=C(C=C1)N=C3C(C2=O)(CCN3C4=CC=CC=C4)O
# 4     C1C(C(OC2=CC(=CC(=C21)O)O)C3=CC(=C(C(=C3)O)O)O...
# ...                                                 ...
# 3118  C[C@@]1(O)C[C@@H](C1)c2nc(c3ccc4ccc(nc4c3)c5cc...
# 3119  CC1=C2C(C(=O)C3(C(CC4C(C3C(C(C2(C)C)(CC1OC(=O)...
# 3120  CC1=NN(C=C1NC2=NC=C(C(=C2)NC3=CC=CC=C3C(=O)NC)...
# 3121  CC1=NN(C=C1NC2=NC=C(C(=C2)NC3=C(C=C(C=C3)F)C(=...
# 3122  CC(C(=O)N1CCC(CC1)C2=CC(=C(C=C2)NC3=NC=C(C(=N3...
#
# [3123 rows x 3 columns]

# %%
# 需要替换的特定值
replace_dict = {
    '3094/9/5': '3094-09-5',
    '6429/4/5': '6429-04-5',
    '7218/4/4': '7218-04-4'
}

# 仅替换指定的 Drug 值
smiles['Drug'] = smiles['Drug'].apply(lambda x: replace_dict[x] if x in replace_dict else x)

# %%
smiles.to_csv("./Drug_smiles.csv",index=False)

# %%
drug_map = np.load('./Drug_map.npy', allow_pickle=True)
drug_map = drug_map.item()

# %%
drug_map
# Out:
# {'(+)-Bicuculline': 0,
#  '(+)-PD 128907 hydrochloride': 1,
#  '(+)-Usnic acid': 2,
#  '(-)-Blebbistatin': 3,
#  '(-)-Epigallocatechin gallate': 4,
#  '(-)-Ethyl apovincaminate': 5,
#  '(-)-MK 801 Maleate': 6,
#  '(-)-Rapamycin': 7,
#  '(-)-chlorpheniramine': 8,
#  '(-)-huperzine A': 9,
#  '(3S,4R)-Tofacitinib': 10,
#  '(E/Z)-ferulic acid': 11,
#  '(Phenylindolyl)maleimide deriv. 79': 12,
#  '(R)-(-)-Rolipram': 13,
#  '(R)-Bicalutamide': 14,
#  '(S)-(+)-rolipram': 15,
#  '.beta.,.beta.-Carotene': 16,
#  '001, RAD': 17,
#  '1,25-dihydroxy vitamin D3': 18,
#  '1-(1-Naphthylmethyl)piperazine': 19,
#  '1-DOCOSANOL': 20,
#  '1-Hexadecanol': 21,
#  '1-Methyl-D-tryptophan': 22,
#  '1-beta-D-Xylofuranosyluracil': 23,
#  '10-Hydroxycamptothecin': 24,
#  '10-epi-Aclacinomycin A': 25,
#  '1001645-58-4': 26,
#  '10030-85-0': 27,
#  '10058-F4': 28,
#  '10074-G5': 29,
#  '1032350-13-2': 30,
#  '10356-76-0': 31,
#  '10402-53-6': 32,
#  '1047953-91-2': 33,
#  '1062368-24-4': 34,
#  '1072959-67-1': 35,
#  '1080622-86-1': 36,
#  '1095382-05-0': 37,
#  '1096708-71-2': 38,
#  '11-cis Retinoic Acid': 39,
#  '110025-28-0': 40,
#  '1111636-35-1': 41,
#  '1118807-13-8': 42,
#  '1124329-14-1': 43,
#  '112648-68-7': 44,
#  '1144068-46-1': 45,
#  '1155877-97-6': 46,
#  '1161205-04-4': 47,
#  '1166227-08-2': 48,
#  '117048-62-1': 49,
#  '1174046-72-0': 50,
#  '1194044-20-6': 51,
#  '1201902-80-8': 52,
#  '1202884-94-3': 53,
#  '1206101-20-3': 54,
#  '1214265-56-1': 55,
#  '122111-05-1': 56,
#  '1221186-53-3': 57,
#  '1222781-70-5': 58,
#  '1224844-38-5': 59,
#  '1231930-82-7': 60,
#  '1243244-14-5': 61,
#  '1246086-78-1': 62,
#  '1247819-59-5': 63,
#  '124936-75-0': 64,
#  '125316-60-1': 65,
#  '1260907-17-2': 66,
#  '1262770-73-9': 67,
#  '1265789-88-5': 68,
#  '1268524-70-4': 69,
#  '128517-07-7': 70,
#  '129-56-6': 71,
#  '1300031-49-5': 72,
#  '1309805-49-9': 73,
#  '1314241-44-5': 74,
#  '1316214-52-4': 75,
#  '131707-23-8': 76,
#  '131848-97-0': 77,
#  '13292-46-1': 78,
#  '133294-37-8': 79,
#  '133550-30-8': 80,
#  '1338259-05-4': 81,
#  '134036-52-5': 82,
#  '13463-41-7': 83,
#  '1346528-06-0': 84,
#  '134680-32-3': 85,
#  '1370261-97-4': 86,
#  '1392399-03-9': 87,
#  '14003-96-4': 88,
#  '1421227-52-2': 89,
#  '1429617-90-2': 90,
#  '1431985-92-0': 91,
#  '143945-86-2': 92,
#  '14402-89-2': 93,
#  '145-13-1': 94,
#  '145986-26-1': 95,
#  '146535-11-7': 96,
#  '14807-96-6': 97,
#  '1485-00-3': 98,
#  '14913-33-8': 99,
#  '15(S)-Fluprostenol isopropyl ester': 100,
#  '152121-47-6': 101,
#  '153436-54-5': 102,
#  '153559-76-3': 103,
#  '154447-35-5': 104,
#  '154447-36-6': 105,
#  '155584-74-0': 106,
#  '158798-73-3': 107,
#  '159351-69-6': 108,
#  '1616632-77-9': 109,
#  '164178-33-0': 110,
#  '164658-13-3': 111,
#  '167465-36-3': 112,
#  '167869-21-8': 113,
#  '17-DMAG (Alvespimycin) HCl': 114,
#  '17-Hydroxypregn-4-en-20-yn-3-one': 115,
#  '172889-26-8': 116,
#  '172889-27-9': 117,
#  '176977-56-3': 118,
#  '178606-66-1': 119,
#  '180083-23-2': 120,
#  '183321-86-0': 121,
#  '185039-99-0': 122,
#  '193611-72-2': 123,
#  '193746-75-7': 124,
#  '1986-47-6': 125,
#  '199433-58-4': 126,
#  '1H-Indole-5-carboxamide': 127,
#  '1beta-Methylimipenem': 128,
#  '2,4,5-TRIMETHOXYBENZALDEHYDE': 129,
#  '2-AMINOTHIAZOLE': 130,
#  '2-Deoxy-D-galactopyranose': 131,
#  '2-Methoxyestradiol': 132,
#  '2-Nitroimidazole': 133,
#  '2-iminobiotin': 134,
#  '2-thiouracil': 135,
#  '20-HYDROXYECDYSONE': 136,
#  '200484-11-3': 137,
#  '20439-47-8': 138,
#  '207679-81-0': 139,
#  '209410-46-8': 140,
#  '209481-20-9': 141,
#  '209984-56-5': 142,
#  '209984-57-6': 143,
#  '21102-95-4': 144,
#  '211096-49-0': 145,
#  '212631-79-3': 146,
#  '218137-86-1': 147,
#  '219580-11-7': 148,
#  '219773-55-4': 149,
#  '227088-94-0': 150,
#  '23541-50-6': 151,
#  '251992-66-2': 152,
#  '252003-65-9': 153,
#  '252916-29-3': 154,
#  '261901-57-9': 155,
#  '264218-23-7': 156,
#  '27726-35-8': 157,
#  '278779-30-9': 158,
#  '280744-09-4': 159,
#  '284028-89-3': 160,
#  '288150-92-5': 161,
#  '29883-15-6': 162,
#  "3'-Epi Gemcitabine (Gemcitabine Impurity)": 163,
#  "3,3'-Diindolylmethane": 164,
#  '3-(2,6-dichloro-3,5-dimethoxy-phenyl)-1-[6-[4-(4-ethylpiperazin-1-yl)anilino]pyrimidin-4-yl]-1-methyl-urea': 165,
#  '3-(3,4-Dihydroxyphenyl)lactate': 166,
#  '3-Deazaneplanocin': 167,
#  '3-aminobenzamide': 168,
#  '3-methyladenine': 169,
#  '301836-41-9': 170,
#  '301836-43-1': 171,
#  '303727-31-3': 172,
#  '30562-34-6': 173,
#  '30675-13-9': 174,
#  '3094-09-5': 175,
#  '309928-48-1': 176,
#  '313516-66-4': 177,
#  '314042-01-8': 178,
#  '314245-33-5': 179,
#  '315183-21-2': 180,
#  '315703-52-7': 181,
#  '317318-70-0': 182,
#  '32981-86-5': 183,
#  '331771-20-1': 184,
#  '33419-42-0': 185,
#  '34031-32-8': 186,
#  '342641-94-5': 187,
#  '347323-96-0': 188,
#  '348622-88-8': 189,
#  '34933-06-7': 190,
#  '356559-20-1': 191,
#  '357263-14-0': 192,
#  '35922-06-6': 193,
#  '371942-69-7': 194,
#  '372196-67-3': 195,
#  '38194-50-2': 196,
#  '386750-22-7': 197,
#  '391210-10-9': 198,
#  '396129-53-6': 199,
#  '4-Aminohippuric acid': 200,
#  '4-Chloro-3-methylphenol': 201,
#  '4-Iodo-3-nitrobenzamide': 202,
#  '4-Methoxyphenol': 203,
#  '4-Methylpyrazole': 204,
#  '4-methylumbelliferone': 205,
#  '405554-55-4': 206,
#  '405911-17-3': 207,
#  '409345-29-5': 208,
#  '41575-94-4': 209,
#  '423735-93-7': 210,
#  '426219-18-3': 211,
#  '431979-47-4': 212,
#  '438190-29-5': 213,
#  '439081-02-4': 214,
#  '444912-48-5': 215,
#  '445430-58-0': 216,
#  '449811-92-1': 217,
#  '451492-95-8': 218,
#  '452342-67-5': 219,
#  '473382-39-7': 220,
#  '476477-15-3': 221,
#  '494772-86-0': 222,
#  '4961-41-5': 223,
#  '497839-62-0': 224,
#  '49843-98-3': 225,
#  '5-Aminolevulinic acid hydrochloride': 226,
#  '5-Aminosalicylic acid': 227,
#  "5-Fluoro-2'-deoxyuridine": 228,
#  '5-Fluorocytosine': 229,
#  '5-Fluorouracil': 230,
#  '5-azacytidine': 231,
#  '5-hydroxy-L-tryptophan': 232,
#  '5-hydroxytryptophan': 233,
#  '500579-04-4': 234,
#  '501919-59-1': 235,
#  '501925-31-1': 236,
#  '503468-95-9': 237,
#  '504433-23-2': 238,
#  '51-56-9': 239,
#  '54-62-6': 240,
#  '545380-34-5': 241,
#  '546141-08-6': 242,
#  '547757-23-3': 243,
#  '55-86-7': 244,
#  '55778-02-4': 245,
#  '56990-57-9': 246,
#  '57-22-7': 247,
#  '57477-39-1': 248,
#  '58131-57-0': 249,
#  '59643-91-3': 250,
#  '5987-82-6': 251,
#  '5Z-7-Oxozeaenol': 252,
#  '6-Mercaptopurine': 253,
#  '6-Thioguanine': 254,
#  '6-aminohexanoic acid': 255,
#  '602306-29-6': 256,
#  '607742-69-8': 257,
#  '61350-00-3': 258,
#  '61618-27-7': 259,
#  '626222-24-0': 260,
#  '629664-81-9': 261,
#  '635318-11-5': 262,
#  '6402-23-9': 263,
#  '6429-04-5': 264,
#  '648450-29-7': 265,
#  '649756-01-4': 266,
#  '65666-07-1': 267,
#  '65678-07-1': 268,
#  '666260-75-9': 269,
#  '667463-62-9': 270,
#  '67469-78-7': 271,
#  '681136-29-8': 272,
#  '6898-97-1': 273,
#  '690206-97-4': 274,
#  '693228-63-6': 275,
#  '7-Aminocephalosporanic acid': 276,
#  '7-Ethyl-10-hydroxycamptothecin': 277,
#  '702675-74-9': 278,
#  '7081-53-0': 279,
#  '711085-63-1': 280,
#  '71555-25-4': 281,
#  '7218-04-4': 282,
#  '722544-51-6': 283,
#  '732302-99-7': 284,
#  '741713-40-6': 285,
#  '761437-28-9': 286,
#  '761439-42-3': 287,
#  '7728-73-6': 288,
#  '7803-88-5': 289,
#  '781661-94-7': 290,
#  '8-AZAGUANINE': 291,
#  '8-Methyl-N-Vanillyl-6-Nonenamide': 292,
#  '80306-38-3': 293,
#  '803712-79-0': 294,
#  '827022-32-2': 295,
#  '83-88-5': 296,
#  '841290-80-0': 297,
#  '844499-71-4': 298,
#  '850173-95-4': 299,
#  '851723-84-7': 300,
#  '852475-26-4': 301,
#  '853910-02-8': 302,
#  '856243-80-6': 303,
#  '865362-74-9': 304,
#  '869288-64-2': 305,
#  '873225-46-8': 306,
#  '878739-06-1': 307,
#  '882257-11-6': 308,
#  '883050-24-6': 309,
#  '885060-08-2': 310,
#  '885692-52-4': 311,
#  '887650-05-7': 312,
#  '891494-63-6': 313,
#  '891494-64-7': 314,
#  '89565-68-4': 315,
#  '89778-26-7': 316,
#  '9-BETA-D-XYLOFURANOSYL-ADENINE': 317,
#  '9-cis Acitretin': 318,
#  '900515-16-4': 319,
#  '905579-51-3': 320,
#  '905586-69-8': 321,
#  '906673-24-3': 322,
#  '908115-27-5': 323,
#  '909910-43-6': 324,
#  '912545-86-9': 325,
#  '913376-84-8': 326,
#  '915019-65-7': 327,
#  '915087-27-3': 328,
#  '915385-81-8 (free base)': 329,
#  '920113-03-7': 330,
#  '925434-55-5': 331,
#  '925705-73-3': 332,
#  '926319-75-7': 333,
#  '928774-43-0': 334,
#  '934593-90-5': 335,
#  '936091-15-5': 336,
#  '936091-56-4': 337,
#  '937174-76-0': 338,
#  '939791-38-5': 339,
#  '940929-33-9': 340,
#  '944261-79-4': 341,
#  '94875-80-6': 342,
#  '951151-97-6': 343,
#  '955-24-8': 344,
#  '957054-30-7': 345,
#  '959122-11-3': 346,
#  '96036-03-2': 347,
#  'A 438079': 348,
#  'A 839977': 349,
#  'A-443654': 350,
#  'A-674563': 351,
#  'A-770041': 352,
#  'ABEXINOSTAT': 353,
#  'ABT-737': 354,
#  'ABT-751': 355,
#  'AC-261066': 356,
#  'AC1MDWZ9': 357,
#  'AC265347': 358,
#  'ACADESINE': 359,
#  'ACC1 BMS': 360,
#  'ACETYLCHOLINE CHLORIDE': 361,
#  'ACHP': 362,
#  'ACIPIMOX': 363,
#  'ADAPALENE': 364,
#  'ADEFOVIR DIPIVOXIL': 365,
#  'ADL5859': 366,
#  'ADM hydrochloride': 367,
#  'ADX-47273': 368,
#  'AG-041R': 369,
#  'AG-1478': 370,
#  'AG14361': 371,
#  'AGI-5198': 372,
#  'AGI-6780': 373,
#  'AIM-100': 374,
#  'AK-7': 375,
#  'ALLYLTHIOUREA': 376,
#  'ALVERINE CITRATE': 377,
#  'AM251': 378,
#  'AMD 473': 379,
#  'AMG-208': 380,
#  'AMG-25': 381,
#  'AMG-458': 382,
#  'AMG-47a': 383,
#  'AMG-51': 384,
#  'AMG-517': 385,
#  'AMG-900': 386,
#  'AMG-Tie2-1': 387,
#  'AMILORIDE': 388,
#  'AMILORIDE HYDROCHLORIDE': 389,
#  'AMPICILLIN SODIUM': 390,
#  'AMPICILLIN TRIHYDRATE': 391,
#  'ANAGRELIDE HYDROCHLORIDE': 392,
#  'ANISOTROPINE METHYLBROMIDE': 393,
#  'AP26113': 394,
#  'APR-246': 395,
#  'AR-42': 396,
#  'AR-A014418': 397,
#  'AR-C155858': 398,
#  'ARN-509': 399,
#  'ARTICAINE HYDROCHLORIDE': 400,
#  'AS-252424': 401,
#  'AS-604850': 402,
#  'AS601245': 403,
#  'ASCORBYL PALMITATE': 404,
#  'ASP3026': 405,
#  'AST-1306': 406,
#  'AT-406': 407,
#  'AT7519': 408,
#  'AT7867': 409,
#  'AT9283': 410,
#  'ATORVASTATIN CALCIUM': 411,
#  'ATOVAQUONE': 412,
#  'ATROPINE': 413,
#  'AVL-292': 414,
#  'AVN-944': 415,
#  'AZ-23': 416,
#  'AZ10606120': 417,
#  'AZ12419304': 418,
#  'AZ12799043': 419,
#  'AZ13406193': 420,
#  'AZ13409007, AKTaz': 421,
#  'AZ13453202': 422,
#  'AZ191': 423,
#  'AZ20': 424,
#  'AZD-26': 425,
#  'AZD-4877': 426,
#  'AZD1080': 427,
#  'AZD1208': 428,
#  'AZD1480': 429,
#  'AZD1981': 430,
#  'AZD2014': 431,
#  'AZD2461': 432,
#  'AZD2858': 433,
#  'AZD3463': 434,
#  'AZD3514': 435,
#  'AZD4320': 436,
#  'AZD4547': 437,
#  'AZD5363': 438,
#  'AZD5582': 439,
#  'AZD6482': 440,
#  'AZD6738': 441,
#  'AZD7545': 442,
#  'AZD7762': 443,
#  'AZD8055': 444,
#  'AZD8186': 445,
#  'AZD8330': 446,
#  'AZELASTINE HYDROCHLORIDE': 447,
#  'AZILSARTAN MEDOXOMIL': 448,
#  'AZLOCILLIN SODIUM': 449,
#  'Abiraterone': 450,
#  'Abiraterone acetate': 451,
#  'Acebutolol hydrochloride': 452,
#  'Aceclidine hydrochloride': 453,
#  'Acesulfame potassium': 454,
#  'Acetovanillone': 455,
#  'Acitazanolast': 456,
#  'Acitretin': 457,
#  'Aclidinium bromide': 458,
#  'Adenine hydrochloride': 459,
#  'Adiphenine hydrochloride': 460,
#  'AdipoRon': 461,
#  'Adrenalone hydrochloride': 462,
#  'Afatinib': 463,
#  'Agomelatine': 464,
#  'Akt inhibitor VIII': 465,
#  'Akt-I-1,2': 466,
#  'Albendazole oxide': 467,
#  'Alectinib': 468,
#  'Alfuzosin Hydrochloride': 469,
#  'Alibendol': 470,
#  'Alisertib': 471,
#  'Aliskiren': 472,
#  'Aliskiren hemifumarate': 473,
#  'Alizarin': 474,
#  'Almotriptan': 475,
#  'Almotriptan malate': 476,
#  'Aloe-emodin': 477,
#  'Alogliptin': 478,
#  'Aloin B': 479,
#  'Aloperine': 480,
#  'Alpelisib(BYL-719)': 481,
#  'Altrenogest': 482,
#  'Amantadine hydrochloride': 483,
#  'Amastatin': 484,
#  'Ambrisentan': 485,
#  'Ambroxol hydrochloride': 486,
#  'Amiodarone hydrochloride': 487,
#  'Amitriptyline hydrochloride': 488,
#  'Ammonium glycyrrhizate': 489,
#  'Amonafide': 490,
#  'Amorolfine': 491,
#  'Amoxicillin sodium': 492,
#  'Amprolium hydrochloride': 493,
#  'Amuvatinib': 494,
#  'Anacetrapib': 495,
#  'Andarine': 496,
#  'Andrographolide': 497,
#  'Antazoline hydrochloride': 498,
#  'Antibiotic AD 32': 499,
#  'Antibiotic AY 22989': 500,
#  'Antimycin A': 501,
#  'Apatinib': 502,
#  'Apilimod': 503,
#  'Apitolisib': 504,
#  'Apixaban': 505,
#  'Apoptosis Activator 2': 506,
#  'Apremilast': 507,
#  'Aprepitant': 508,
#  'Arbidol': 509,
#  'Aripiprazole': 510,
#  'Arry-380': 511,
#  'Artemether': 512,
#  'Artesunate': 513,
#  'Asenapine': 514,
#  'Asiatic acid': 515,
#  'Astragaloside A': 516,
#  'Ataluren': 517,
#  'Atazanavir': 518,
#  'Atazanavir sulfate': 519,
#  'Atomoxetine hydrochloride': 520,
#  'Atopaxar': 521,
#  'Atracurium besylate': 522,
#  'Aurora A Inhibitor I': 523,
#  'Avagacestat': 524,
#  'Avanafil': 525,
#  'Avasimibe': 526,
#  'Avobenzone': 527,
#  'Axitinib': 528,
#  'Azacyclonol': 529,
#  'Azacytidine, 5-': 530,
#  'Azaperone': 531,
#  'Azasetron': 532,
#  'Azatadine maleate': 533,
#  'Azelnidipine': 534,
#  'Azilsartan': 535,
#  'B022': 536,
#  'BAF312': 537,
#  'BALSALAZIDE': 538,
#  'BAM7': 539,
#  'BAY 61-3606': 540,
#  'BAY-41-8543': 541,
#  'BCP07985': 542,
#  'BD-1047': 543,
#  'BECLOMETHASONE DIPROPIONATE': 544,
#  'BENAZEPRIL HYDROCHLORIDE': 545,
#  'BENDROFLUMETHIAZIDE': 546,
#  'BENSERAZIDE HYDROCHLORIDE': 547,
#  'BENZTROPINE MESYLATE': 548,
#  'BEPHENIUM HYDROXYNAPHTHOATE': 549,
#  'BETAMETHASONE DIPROPIONATE': 550,
#  'BETAMETHASONE VALERATE': 551,
#  'BGT-226 free base': 552,
#  'BI 2536': 553,
#  'BI-671800': 554,
#  'BI-78D3': 555,
#  'BI-D1870': 556,
#  'BI605906': 557,
#  'BIBR 1532': 558,
#  'BIBR-1048': 559,
#  'BIBR-1532': 560,
#  'BIIB021': 561,
#  'BISOPROLOL': 562,
#  'BIX 02189': 563,
#  'BIX-01294': 564,
#  'BIX02188': 565,
#  'BML-190': 566,
#  'BML-277': 567,
#  'BMS 299897': 568,
#  'BMS-2': 569,
#  'BMS-265246': 570,
#  'BMS-3': 571,
#  'BMS-378806': 572,
#  'BMS-5': 573,
#  'BMS-536924': 574,
#  'BMS-599626': 575,
#  'BMS-707035': 576,
#  'BMS-754807': 577,
#  'BMS-777607': 578,
#  'BMS-833923': 579,
#  'BMS-911543': 580,
#  'BP-1-102': 581,
#  'BRIMONIDINE TARTRATE': 582,
#  'BRL 15572': 583,
#  'BROMFENAC SODIUM': 584,
#  'BRUCINE': 585,
#  'BS-181': 586,
#  'BS-181 HCl': 587,
#  'BS-194': 588,
#  'BTZ043 Racemate': 589,
#  'BUTHIONINE SULFOXIMINE': 590,
#  'BUTOCONAZOLE NITRATE': 591,
#  'BX-912': 592,
#  'Baicalin': 593,
#  'Balofloxacin': 594,
#  'Banoxantrone': 595,
#  'Bardoxolone methyl': 596,
#  'Baricitinib': 597,
#  'Bayer-18': 598,
#  'Bazedoxifene HCl': 599,
#  'Bazedoxifene acetate': 600,
#  'Belinostat': 601,
#  'Belinostat(Random Configuration)': 602,
#  'Bendamustine': 603,
#  'Bendamustine hydrochloride': 604,
#  'Benzamil': 605,
#  'Benzydamine hydrochloride': 606,
#  'Bepotastine besilate': 607,
#  'Bergapten': 608,
#  'Bestatin': 609,
#  'Betahistine dihydrochloride': 610,
#  'Betamipron': 611,
#  'Bethanechol chloride': 612,
#  'Bexarotene': 613,
#  'Bilobalide': 614,
#  'Bimatoprost': 615,
#  'Bindarit': 616,
#  'Binimetinib': 617,
#  'Bioepiderm': 618,
#  'Biperiden hydrochloride': 619,
#  'Birinapant': 620,
#  'Bisoprolol fumarate': 621,
#  'Bleomycin sulfate': 622,
#  'Bortezomib': 623,
#  'Bosentan hydrate': 624,
#  'Bosutinib': 625,
#  'Bracken fern toxic component': 626,
#  'Brinzolamide': 627,
#  'Brivanib': 628,
#  'Brivanib alaninate': 629,
#  'Bromhexine hydrochloride': 630,
#  'Brompheniramine maleate': 631,
#  'Buflomedil': 632,
#  'Buflomedil hydrochloride': 633,
#  'Buparlisib': 634,
#  'Bupivacaine hydrochloride': 635,
#  'Buspirone hydrochloride': 636,
#  'Butenafine hydrochloride': 637,
#  'Butoconazole': 638,
#  'C188-9': 639,
#  'C9H16N2O4S': 640,
#  'CABAZITAXEL': 641,
#  'CALCIUM GLUCEPTATE': 642,
#  'CAPECITABINE': 643,
#  'CARBENOXOLONE SODIUM': 644,
#  'CASIN': 645,
#  'CAY-10581': 646,
#  'CAY10505': 647,
#  'CAY10603': 648,
#  'CBiol_001725': 649,
#  'CBiol_001848': 650,
#  'CBiol_001931': 651,
#  'CBiol_002052': 652,
#  'CC-401': 653,
#  'CCT-018159': 654,
#  'CCT128930': 655,
#  'CCT129202': 656,
#  'CDIBA': 657,
#  'CDK9 inhibitor': 658,
#  'CEP-32496': 659,
#  'CEP-33779': 660,
#  'CEPHARANTHINE': 661,
#  'CFTRinh-172': 662,
#  'CGI-1746': 663,
#  'CGK733': 664,
#  'CGS 21680 hydrochloride': 665,
#  'CH5132799': 666,
#  'CHEBI:45367': 667,
#  'CHEBI:47495': 668,
#  'CHEBI:63449': 669,
#  'CHEBI:93770': 670,
#  'CHEBI:94798': 671,
#  'CHEBI:95054': 672,
#  'CHEMBL1090466': 673,
#  'CHEMBL1221434': 674,
#  'CHEMBL1254007': 675,
#  'CHEMBL1270810': 676,
#  'CHEMBL1288002': 677,
#  'CHEMBL130321': 678,
#  'CHEMBL1316023': 679,
#  'CHEMBL1364159': 680,
#  'CHEMBL1394734': 681,
#  'CHEMBL1408258': 682,
#  'CHEMBL1625478': 683,
#  'CHEMBL1625829': 684,
#  'CHEMBL166161': 685,
#  'CHEMBL1706473': 686,
#  'CHEMBL1706858': 687,
#  'CHEMBL1739063': 688,
#  'CHEMBL17639': 689,
#  'CHEMBL1824695': 690,
#  'CHEMBL1836853': 691,
#  'CHEMBL1950303': 692,
#  'CHEMBL2018451': 693,
#  'CHEMBL2062101': 694,
#  'CHEMBL2132441': 695,
#  'CHEMBL2133870': 696,
#  'CHEMBL2134570': 697,
#  'CHEMBL213634': 698,
#  'CHEMBL2136663': 699,
#  'CHEMBL2138817': 700,
#  'CHEMBL2140543': 701,
#  'CHEMBL2140838': 702,
#  'CHEMBL2140972': 703,
#  'CHEMBL2141387': 704,
#  'CHEMBL2141644': 705,
#  'CHEMBL2143037': 706,
#  'CHEMBL2144690': 707,
#  'CHEMBL2426174': 708,
#  'CHEMBL256963': 709,
#  'CHEMBL258622': 710,
#  'CHEMBL277800': 711,
#  'CHEMBL3103191': 712,
#  'CHEMBL3103192': 713,
#  'CHEMBL317493': 714,
#  'CHEMBL3182364': 715,
#  'CHEMBL3182641': 716,
#  'CHEMBL3183697': 717,
#  'CHEMBL3183888': 718,
#  'CHEMBL3184303': 719,
#  'CHEMBL3184387': 720,
#  'CHEMBL3184424': 721,
#  'CHEMBL3184655': 722,
#  'CHEMBL3185999': 723,
#  'CHEMBL3186547': 724,
#  'CHEMBL3186716': 725,
#  'CHEMBL3186846': 726,
#  'CHEMBL3188521': 727,
#  'CHEMBL3188552': 728,
#  'CHEMBL3188661': 729,
#  'CHEMBL3188944': 730,
#  'CHEMBL3191144': 731,
#  'CHEMBL3322515': 732,
#  'CHEMBL3348822': 733,
#  'CHEMBL3348824': 734,
#  'CHEMBL3348829': 735,
#  'CHEMBL3348835': 736,
#  'CHEMBL3348838': 737,
#  'CHEMBL3348841': 738,
#  'CHEMBL3348843': 739,
#  'CHEMBL3348847': 740,
#  'CHEMBL3348848': 741,
#  'CHEMBL3348849': 742,
#  'CHEMBL3348853': 743,
#  'CHEMBL3348857': 744,
#  'CHEMBL3348858': 745,
#  'CHEMBL3348860': 746,
#  'CHEMBL3348869': 747,
#  'CHEMBL3348870': 748,
#  'CHEMBL3348871': 749,
#  'CHEMBL3348872': 750,
#  'CHEMBL3348874': 751,
#  'CHEMBL3348877': 752,
#  'CHEMBL3348879': 753,
#  'CHEMBL3348881': 754,
#  'CHEMBL3348883': 755,
#  'CHEMBL3348884': 756,
#  'CHEMBL3348885': 757,
#  'CHEMBL3348886': 758,
#  'CHEMBL3348887': 759,
#  'CHEMBL3348888': 760,
#  'CHEMBL3348890': 761,
#  'CHEMBL3348891': 762,
#  'CHEMBL3348892': 763,
#  'CHEMBL3348894': 764,
#  'CHEMBL3348895': 765,
#  'CHEMBL3348899': 766,
#  'CHEMBL3348900': 767,
#  'CHEMBL3348905': 768,
#  'CHEMBL3348910': 769,
#  'CHEMBL3348914': 770,
#  'CHEMBL3348916': 771,
#  'CHEMBL3348918': 772,
#  'CHEMBL3348919': 773,
#  'CHEMBL3348922': 774,
#  'CHEMBL3348924': 775,
#  'CHEMBL3348925': 776,
#  'CHEMBL3348926': 777,
#  'CHEMBL3348927': 778,
#  'CHEMBL3348928': 779,
#  'CHEMBL3348929': 780,
#  'CHEMBL3348930': 781,
#  'CHEMBL3348931': 782,
#  'CHEMBL3348934': 783,
#  'CHEMBL3348935': 784,
#  'CHEMBL3348941': 785,
#  'CHEMBL3348942': 786,
#  'CHEMBL3348944': 787,
#  'CHEMBL3348946': 788,
#  'CHEMBL3348947': 789,
#  'CHEMBL3348948': 790,
#  'CHEMBL3348949': 791,
#  'CHEMBL3348950': 792,
#  'CHEMBL3348952': 793,
#  'CHEMBL3348953': 794,
#  'CHEMBL3348954': 795,
#  'CHEMBL3348955': 796,
#  'CHEMBL3348956': 797,
#  'CHEMBL3348959': 798,
#  'CHEMBL3348961': 799,
#  'CHEMBL3348967': 800,
#  'CHEMBL3348973': 801,
#  'CHEMBL3348974': 802,
#  'CHEMBL3348975': 803,
#  'CHEMBL3348980': 804,
#  'CHEMBL3348982': 805,
#  'CHEMBL3348985': 806,
#  'CHEMBL3348987': 807,
#  'CHEMBL3348988': 808,
#  'CHEMBL3348989': 809,
#  'CHEMBL3348991': 810,
#  'CHEMBL3348995': 811,
#  'CHEMBL3348997': 812,
#  'CHEMBL3349002': 813,
#  'CHEMBL3349004': 814,
#  'CHEMBL3349010': 815,
#  'CHEMBL3349012': 816,
#  'CHEMBL3349015': 817,
#  'CHEMBL3417706': 818,
#  'CHEMBL34450': 819,
#  'CHEMBL3814532': 820,
#  'CHEMBL3856067': 821,
#  'CHEMBL387477': 822,
#  'CHEMBL3923667': 823,
#  'CHEMBL39740': 824,
#  'CHEMBL416657': 825,
#  'CHEMBL4303286': 826,
#  'CHEMBL431383': 827,
#  'CHEMBL492193': 828,
#  'CHEMBL494027': 829,
#  'CHEMBL75474': 830,
#  'CHIR-124': 831,
#  'CHIR-98014': 832,
#  'CHIR-99021': 833,
#  'CHIR-99021 HCl': 834,
#  'CHLORAMPHENICOL PALMITATE': 835,
#  'CHLOROGENIC ACID': 836,
#  'CHOLINE CHLORIDE': 837,
#  'CI-988': 838,
#  'CICLOPIROX': 839,
#  'CILAZAPRIL MONOHYDRATE': 840,
#  'CINCHONIDINE': 841,
#  'CLEMASTINE FUMARATE': 842,
#  'CLOBETASOL PROPIONATE': 843,
#  'CLONIDINE HYDROCHLORIDE': 844,
#  'CLORSULON': 845,
#  'CNX-774': 846,
#  'CORTISONE ACETATE': 847,
#  'CP-673451': 848,
#  'CP-724714': 849,
#  'CP-91149': 850,
#  'CPG-52364': 851,
#  'CPI-613': 852,
#  'CRTh2 antagonist 2': 853,
#  'CTEP': 854,
#  'CTK8E8456': 855,
#  'CTK9A1709': 856,
#  'CUDC-101': 857,
#  'CUDC-907': 858,
#  'CVT-6883': 859,
#  'CX-5461': 860,
#  'CYP3cide': 861,
#  'CYPROHEPTADINE': 862,
#  'CYPROTERONE ACETATE': 863,
#  'CYROMAZINE': 864,
#  'CYTARABINE HYDROCHLORIDE': 865,
#  'CYTISINE': 866,
#  'CZC24832': 867,
#  'Cabozantinib': 868,
#  'Caffeic acid phenethyl ester': 869,
#  'Caffeine citrate': 870,
#  'Calcifediol': 871,
#  'Calmidazolium': 872,
#  'Camostat': 873,
#  'Camostat mesylate': 874,
#  'Canadine': 875,
#  'Canagliflozin': 876,
#  'Candesartan cilexetil': 877,
#  'Canertinib': 878,
#  'Capecitabine (Xeloda)': 879,
#  'Carbenicillin disodium': 880,
#  'Carbimazole': 881,
#  'Carboplatin Paclitaxel': 882,
#  'Carboplatinum': 883,
#  'Carboxyamidotriazole': 884,
#  'Cardamonin': 885,
#  'Cardiogenol C': 886,
#  'Carfilzomib': 887,
#  'Caroverine': 888,
#  'Caspofungin acetate': 889,
#  'Catharanthine': 890,
#  'Cathepsin inhibitor 1': 891,
#  'Cdk/Crk Inhibitor': 892,
#  'Cdk4/6 Inhibitor IV': 893,
#  'Cediranib': 894,
#  'Cefoselis sulfate': 895,
#  'Cefprozil monohydrate': 896,
#  'Ceftiofur': 897,
#  'Ceftiofur hydrochloride': 898,
#  'Cephalomannine': 899,
#  'Cetirizine dihydrochloride': 900,
#  'Cetrimonium bromide': 901,
#  'Chlorhexidine Base': 902,
#  'Chloropyramine hydrochloride': 903,
#  'Chlorpheniramine maleate': 904,
#  'Chlorpromazine hydrochloride': 905,
#  'Chlorquinaldol': 906,
#  'Chrysophanol': 907,
#  'Ciclopirox olamine': 908,
#  'Cidofovir': 909,
#  'Cilengitide': 910,
#  'Ciliobrevin D': 911,
#  'Cilomilast': 912,
#  'Cinacalcet': 913,
#  'Cinacalcet hydrochloride': 914,
#  'Cinchophen': 915,
#  'Ciprofibrate': 916,
#  'Cisatracurium besylate': 917,
#  'Cl-F-araA': 918,
#  'Cladribine': 919,
#  'Clevidipine': 920,
#  'Clevudine': 921,
#  'Climbazole': 922,
#  'Clindamycin hydrochloride': 923,
#  'Clindamycin palmitate HCl': 924,
#  'Clofarabine': 925,
#  'Clomifene citrate': 926,
#  'Clomipramine hydrochloride': 927,
#  'Closantel': 928,
#  'Closantel sodium': 929,
#  'Cloxacillin sodium': 930,
#  'Co-V': 931,
#  'Cobicistat': 932,
#  'Cobimetinib (R-enantiomer)': 933,
#  'Coenzyme Q10': 934,
#  'Conivaptan': 935,
#  'Conivaptan hydrochloride': 936,
#  'Copanlisib': 937,
#  'Costunolide': 938,
#  'Cot inhibitor-2': 939,
#  'Crenolanib': 940,
#  'Crizotinib': 941,
#  'Cryptotanshinone': 942,
#  'Crystal violet': 943,
#  'Curcumol': 944,
#  'Cutamesine': 945,
#  'Cyclamic acid': 946,
#  'Cyclizine 2HCl': 947,
#  'Cyclocytidine hydrochloride': 948,
#  'Cyclovirobuxine D': 949,
#  'Cyprodime': 950,
#  'Cysteamine hydrochloride': 951,
#  'Cyt387': 952,
#  'D(+)-Glucose': 953,
#  'D-106669': 954,
#  'D-Penicillamine': 955,
#  'D-Sorbitol': 956,
#  'D-Xyl': 957,
#  'D-cycloserine': 958,
#  'D-mannitol': 959,
#  'DANOPREVIR': 960,
#  'DAPTOMYCIN': 961,
#  'DASA-58': 962,
#  'DBeQ': 963,
#  'DECAMETHONIUM BROMIDE': 964,
#  'DEFLAZACORT': 965,
#  'DESONIDE': 966,
#  'DETOMIDINE HYDROCHLORIDE': 967,
#  'DEXMEDETOMIDINE': 968,
#  'DICLAZURIL': 969,
#  'DIFLOXACIN HYDROCHLORIDE': 970,
#  'DIPERODON HYDROCHLORIDE': 971,
#  'DIPHEMANIL METHYLSULFATE': 972,
#  'DIPHENHYDRAMINE HYDROCHLORIDE': 973,
#  'DIVALPROEX SODIUM': 974,
#  'DIZOCILPINE': 975,
#  'DL-Carnitine hydrochloride': 976,
#  'DMXAA': 977,
#  'DOXOFYLLINE': 978,
#  'DSSTox_CID_16760': 979,
#  'DSSTox_CID_20664': 980,
#  'DSSTox_CID_28582': 981,
#  'DU-21220': 982,
#  'DULOXETINE HYDROCHLORIDE': 983,
#  'Dabigatran': 984,
#  'Dabigatran etexilate mesylate': 985,
#  'Dabrafenib': 986,
#  'Dacinostat': 987,
#  'Daclatasvir': 988,
#  'Dacomitinib': 989,
#  'Dalcetrapib': 990,
#  'Daminozide': 991,
#  'Danusertib': 992,
#  'Dapagliflozin': 993,
#  'Dapagliflozin C-2 Epimer': 994,
#  'Dapivirine': 995,
#  'Daporinad': 996,
#  'Dapoxetine': 997,
#  'Dapoxetine hydrochloride': 998,
#  'Darifenacin hydrobromide': 999,
#  ...}

# %%
drug_list_from_dict = set(drug_map.keys())

# %%
drug_list_from_csv = set(smiles['Drug'].str.strip())

# %%
missing_in_dict = drug_list_from_csv - drug_list_from_dict

# %%
missing_in_dict
# Out:
# set()

# %%
drug_dict = {}
for key in drug_map:
    drug_dict[key] = smiles2graph(smiles.loc[smiles['Drug']==key,'SMILES'].values[0])

# %%
drug_dict
# Out:
# {'(+)-Bicuculline': Data(x=[27, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '(+)-PD 128907 hydrochloride': Data(x=[19, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  '(+)-Usnic acid': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '(-)-Blebbistatin': Data(x=[22, 77], edge_index=[2, 50], edge_attr=[50, 4], dtype=torch.float32),
#  '(-)-Epigallocatechin gallate': Data(x=[33, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  '(-)-Ethyl apovincaminate': Data(x=[26, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  '(-)-MK 801 Maleate': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '(-)-Rapamycin': Data(x=[65, 77], edge_index=[2, 136], edge_attr=[136, 4], dtype=torch.float32),
#  '(-)-chlorpheniramine': Data(x=[19, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  '(-)-huperzine A': Data(x=[18, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  '(3S,4R)-Tofacitinib': Data(x=[23, 77], edge_index=[2, 50], edge_attr=[50, 4], dtype=torch.float32),
#  '(E/Z)-ferulic acid': Data(x=[14, 77], edge_index=[2, 28], edge_attr=[28, 4], dtype=torch.float32),
#  '(Phenylindolyl)maleimide deriv. 79': Data(x=[25, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  '(R)-(-)-Rolipram': Data(x=[20, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  '(R)-Bicalutamide': Data(x=[29, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  '(S)-(+)-rolipram': Data(x=[20, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  '.beta.,.beta.-Carotene': Data(x=[40, 77], edge_index=[2, 82], edge_attr=[82, 4], dtype=torch.float32),
#  '001, RAD': Data(x=[68, 77], edge_index=[2, 142], edge_attr=[142, 4], dtype=torch.float32),
#  '1,25-dihydroxy vitamin D3': Data(x=[30, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '1-(1-Naphthylmethyl)piperazine': Data(x=[17, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  '1-DOCOSANOL': Data(x=[23, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  '1-Hexadecanol': Data(x=[17, 77], edge_index=[2, 32], edge_attr=[32, 4], dtype=torch.float32),
#  '1-Methyl-D-tryptophan': Data(x=[16, 77], edge_index=[2, 34], edge_attr=[34, 4], dtype=torch.float32),
#  '1-beta-D-Xylofuranosyluracil': Data(x=[17, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  '10-Hydroxycamptothecin': Data(x=[27, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '10-epi-Aclacinomycin A': Data(x=[58, 77], edge_index=[2, 128], edge_attr=[128, 4], dtype=torch.float32),
#  '1001645-58-4': Data(x=[35, 77], edge_index=[2, 78], edge_attr=[78, 4], dtype=torch.float32),
#  '10030-85-0': Data(x=[12, 77], edge_index=[2, 20], edge_attr=[20, 4], dtype=torch.float32),
#  '10058-F4': Data(x=[16, 77], edge_index=[2, 34], edge_attr=[34, 4], dtype=torch.float32),
#  '10074-G5': Data(x=[25, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  '1032350-13-2': Data(x=[33, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  '10356-76-0': Data(x=[17, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  '10402-53-6': Data(x=[30, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  '1047953-91-2': Data(x=[29, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '1062368-24-4': Data(x=[31, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  '1072959-67-1': Data(x=[30, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  '1080622-86-1': Data(x=[26, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  '1095382-05-0': Data(x=[36, 77], edge_index=[2, 82], edge_attr=[82, 4], dtype=torch.float32),
#  '1096708-71-2': Data(x=[32, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  '11-cis Retinoic Acid': Data(x=[22, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  '110025-28-0': Data(x=[28, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  '1111636-35-1': Data(x=[29, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '1118807-13-8': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '1124329-14-1': Data(x=[33, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  '112648-68-7': Data(x=[34, 77], edge_index=[2, 76], edge_attr=[76, 4], dtype=torch.float32),
#  '1144068-46-1': Data(x=[38, 77], edge_index=[2, 88], edge_attr=[88, 4], dtype=torch.float32),
#  '1155877-97-6': Data(x=[26, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  '1161205-04-4': Data(x=[18, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  '1166227-08-2': Data(x=[26, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  '117048-62-1': Data(x=[23, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  '1174046-72-0': Data(x=[33, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  '1194044-20-6': Data(x=[22, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  '1201902-80-8': Data(x=[34, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  '1202884-94-3': Data(x=[45, 77], edge_index=[2, 98], edge_attr=[98, 4], dtype=torch.float32),
#  '1206101-20-3': Data(x=[30, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  '1214265-56-1': Data(x=[33, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  '122111-05-1': Data(x=[19, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  '1221186-53-3': Data(x=[25, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  '1222781-70-5': Data(x=[22, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  '1224844-38-5': Data(x=[23, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  '1231930-82-7': Data(x=[42, 77], edge_index=[2, 90], edge_attr=[90, 4], dtype=torch.float32),
#  '1243244-14-5': Data(x=[30, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  '1246086-78-1': Data(x=[27, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  '1247819-59-5': Data(x=[20, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  '124936-75-0': Data(x=[25, 77], edge_index=[2, 50], edge_attr=[50, 4], dtype=torch.float32),
#  '125316-60-1': Data(x=[30, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  '1260907-17-2': Data(x=[30, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  '1262770-73-9': Data(x=[24, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  '1265789-88-5': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '1268524-70-4': Data(x=[31, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  '128517-07-7': Data(x=[36, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  '129-56-6': Data(x=[17, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  '1300031-49-5': Data(x=[31, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  '1309805-49-9': Data(x=[35, 77], edge_index=[2, 82], edge_attr=[82, 4], dtype=torch.float32),
#  '1314241-44-5': Data(x=[20, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  '1316214-52-4': Data(x=[32, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  '131707-23-8': Data(x=[30, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '131848-97-0': Data(x=[32, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  '13292-46-1': Data(x=[59, 77], edge_index=[2, 126], edge_attr=[126, 4], dtype=torch.float32),
#  '133294-37-8': Data(x=[17, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  '133550-30-8': Data(x=[22, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  '1338259-05-4': Data(x=[41, 77], edge_index=[2, 90], edge_attr=[90, 4], dtype=torch.float32),
#  '134036-52-5': Data(x=[22, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  '13463-41-7': Data(x=[17, 77], edge_index=[2, 32], edge_attr=[32, 4], dtype=torch.float32),
#  '1346528-06-0': Data(x=[28, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '134680-32-3': Data(x=[15, 77], edge_index=[2, 32], edge_attr=[32, 4], dtype=torch.float32),
#  '1370261-97-4': Data(x=[30, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '1392399-03-9': Data(x=[39, 77], edge_index=[2, 80], edge_attr=[80, 4], dtype=torch.float32),
#  '14003-96-4': Data(x=[15, 77], edge_index=[2, 32], edge_attr=[32, 4], dtype=torch.float32),
#  '1421227-52-2': Data(x=[41, 77], edge_index=[2, 90], edge_attr=[90, 4], dtype=torch.float32),
#  '1429617-90-2': Data(x=[40, 77], edge_index=[2, 88], edge_attr=[88, 4], dtype=torch.float32),
#  '1431985-92-0': Data(x=[26, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  '143945-86-2': Data(x=[17, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  '14402-89-2': Data(x=[15, 77], edge_index=[2, 12], edge_attr=[12, 4], dtype=torch.float32),
#  '145-13-1': Data(x=[23, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  '145986-26-1': Data(x=[16, 77], edge_index=[2, 34], edge_attr=[34, 4], dtype=torch.float32),
#  '146535-11-7': Data(x=[20, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  '14807-96-6': Data(x=[19, 77], edge_index=[2, 22], edge_attr=[22, 4], dtype=torch.float32),
#  '1485-00-3': Data(x=[14, 77], edge_index=[2, 30], edge_attr=[30, 4], dtype=torch.float32),
#  '14913-33-8': Data(x=[5, 77], edge_index=[2, 4], edge_attr=[4, 4], dtype=torch.float32),
#  '15(S)-Fluprostenol isopropyl ester': Data(x=[35, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  '152121-47-6': Data(x=[27, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  '153436-54-5': Data(x=[22, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  '153559-76-3': Data(x=[27, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  '154447-35-5': Data(x=[21, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  '154447-36-6': Data(x=[23, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  '155584-74-0': Data(x=[18, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  '158798-73-3': Data(x=[25, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  '159351-69-6': Data(x=[68, 77], edge_index=[2, 142], edge_attr=[142, 4], dtype=torch.float32),
#  '1616632-77-9': Data(x=[29, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  '164178-33-0': Data(x=[29, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '164658-13-3': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '167465-36-3': Data(x=[42, 77], edge_index=[2, 90], edge_attr=[90, 4], dtype=torch.float32),
#  '167869-21-8': Data(x=[20, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  '17-DMAG (Alvespimycin) HCl': Data(x=[45, 77], edge_index=[2, 90], edge_attr=[90, 4], dtype=torch.float32),
#  '17-Hydroxypregn-4-en-20-yn-3-one': Data(x=[23, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  '172889-26-8': Data(x=[21, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  '172889-27-9': Data(x=[21, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  '176977-56-3': Data(x=[29, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '178606-66-1': Data(x=[21, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  '180083-23-2': Data(x=[39, 77], edge_index=[2, 90], edge_attr=[90, 4], dtype=torch.float32),
#  '183321-86-0': Data(x=[28, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  '185039-99-0': Data(x=[30, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  '193611-72-2': Data(x=[31, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '193746-75-7': Data(x=[26, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  '1986-47-6': Data(x=[11, 77], edge_index=[2, 22], edge_attr=[22, 4], dtype=torch.float32),
#  '199433-58-4': Data(x=[21, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  '1H-Indole-5-carboxamide': Data(x=[12, 77], edge_index=[2, 26], edge_attr=[26, 4], dtype=torch.float32),
#  '1beta-Methylimipenem': Data(x=[21, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  '2,4,5-TRIMETHOXYBENZALDEHYDE': Data(x=[14, 77], edge_index=[2, 28], edge_attr=[28, 4], dtype=torch.float32),
#  '2-AMINOTHIAZOLE': Data(x=[6, 77], edge_index=[2, 12], edge_attr=[12, 4], dtype=torch.float32),
#  '2-Deoxy-D-galactopyranose': Data(x=[11, 77], edge_index=[2, 22], edge_attr=[22, 4], dtype=torch.float32),
#  '2-Methoxyestradiol': Data(x=[22, 77], edge_index=[2, 50], edge_attr=[50, 4], dtype=torch.float32),
#  '2-Nitroimidazole': Data(x=[8, 77], edge_index=[2, 16], edge_attr=[16, 4], dtype=torch.float32),
#  '2-iminobiotin': Data(x=[16, 77], edge_index=[2, 34], edge_attr=[34, 4], dtype=torch.float32),
#  '2-thiouracil': Data(x=[8, 77], edge_index=[2, 16], edge_attr=[16, 4], dtype=torch.float32),
#  '20-HYDROXYECDYSONE': Data(x=[34, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  '200484-11-3': Data(x=[26, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '20439-47-8': Data(x=[8, 77], edge_index=[2, 16], edge_attr=[16, 4], dtype=torch.float32),
#  '207679-81-0': Data(x=[25, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  '209410-46-8': Data(x=[28, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '209481-20-9': Data(x=[29, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '209984-56-5': Data(x=[34, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  '209984-57-6': Data(x=[35, 77], edge_index=[2, 76], edge_attr=[76, 4], dtype=torch.float32),
#  '21102-95-4': Data(x=[30, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '211096-49-0': Data(x=[22, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  '212631-79-3': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '218137-86-1': Data(x=[18, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  '219580-11-7': Data(x=[38, 77], edge_index=[2, 80], edge_attr=[80, 4], dtype=torch.float32),
#  '219773-55-4': Data(x=[26, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  '227088-94-0': Data(x=[33, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  '23541-50-6': Data(x=[39, 77], edge_index=[2, 84], edge_attr=[84, 4], dtype=torch.float32),
#  '251992-66-2': Data(x=[20, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  '252003-65-9': Data(x=[32, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  '252916-29-3': Data(x=[23, 77], edge_index=[2, 50], edge_attr=[50, 4], dtype=torch.float32),
#  '261901-57-9': Data(x=[25, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  '264218-23-7': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '27726-35-8': Data(x=[24, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  '278779-30-9': Data(x=[36, 77], edge_index=[2, 78], edge_attr=[78, 4], dtype=torch.float32),
#  '280744-09-4': Data(x=[25, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  '284028-89-3': Data(x=[21, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  '288150-92-5': Data(x=[26, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  '29883-15-6': Data(x=[32, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  "3'-Epi Gemcitabine (Gemcitabine Impurity)": Data(x=[18, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  "3,3'-Diindolylmethane": Data(x=[19, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  '3-(2,6-dichloro-3,5-dimethoxy-phenyl)-1-[6-[4-(4-ethylpiperazin-1-yl)anilino]pyrimidin-4-yl]-1-methyl-urea': Data(x=[38, 77], edge_index=[2, 82], edge_attr=[82, 4], dtype=torch.float32),
#  '3-(3,4-Dihydroxyphenyl)lactate': Data(x=[14, 77], edge_index=[2, 28], edge_attr=[28, 4], dtype=torch.float32),
#  '3-Deazaneplanocin': Data(x=[19, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  '3-aminobenzamide': Data(x=[10, 77], edge_index=[2, 20], edge_attr=[20, 4], dtype=torch.float32),
#  '3-methyladenine': Data(x=[11, 77], edge_index=[2, 24], edge_attr=[24, 4], dtype=torch.float32),
#  '301836-41-9': Data(x=[29, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  '301836-43-1': Data(x=[30, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  '303727-31-3': Data(x=[25, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  '30562-34-6': Data(x=[40, 77], edge_index=[2, 82], edge_attr=[82, 4], dtype=torch.float32),
#  '30675-13-9': Data(x=[15, 77], edge_index=[2, 32], edge_attr=[32, 4], dtype=torch.float32),
#  '3094-09-5': Data(x=[17, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  '309928-48-1': Data(x=[28, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '313516-66-4': Data(x=[19, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  '314042-01-8': Data(x=[26, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  '314245-33-5': Data(x=[22, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  '315183-21-2': Data(x=[29, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '315703-52-7': Data(x=[25, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  '317318-70-0': Data(x=[30, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '32981-86-5': Data(x=[39, 77], edge_index=[2, 86], edge_attr=[86, 4], dtype=torch.float32),
#  '331771-20-1': Data(x=[38, 77], edge_index=[2, 84], edge_attr=[84, 4], dtype=torch.float32),
#  '33419-42-0': Data(x=[42, 77], edge_index=[2, 96], edge_attr=[96, 4], dtype=torch.float32),
#  '34031-32-8': Data(x=[32, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  '342641-94-5': Data(x=[29, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '347323-96-0': Data(x=[27, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '348622-88-8': Data(x=[23, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  '34933-06-7': Data(x=[29, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '356559-20-1': Data(x=[26, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  '357263-14-0': Data(x=[30, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  '35922-06-6': Data(x=[30, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  '371942-69-7': Data(x=[35, 77], edge_index=[2, 80], edge_attr=[80, 4], dtype=torch.float32),
#  '372196-67-3': Data(x=[27, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  '38194-50-2': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '386750-22-7': Data(x=[28, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '391210-10-9': Data(x=[26, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '396129-53-6': Data(x=[21, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  '4-Aminohippuric acid': Data(x=[14, 77], edge_index=[2, 28], edge_attr=[28, 4], dtype=torch.float32),
#  '4-Chloro-3-methylphenol': Data(x=[9, 77], edge_index=[2, 18], edge_attr=[18, 4], dtype=torch.float32),
#  '4-Iodo-3-nitrobenzamide': Data(x=[13, 77], edge_index=[2, 26], edge_attr=[26, 4], dtype=torch.float32),
#  '4-Methoxyphenol': Data(x=[9, 77], edge_index=[2, 18], edge_attr=[18, 4], dtype=torch.float32),
#  '4-Methylpyrazole': Data(x=[6, 77], edge_index=[2, 12], edge_attr=[12, 4], dtype=torch.float32),
#  '4-methylumbelliferone': Data(x=[13, 77], edge_index=[2, 28], edge_attr=[28, 4], dtype=torch.float32),
#  '405554-55-4': Data(x=[34, 77], edge_index=[2, 76], edge_attr=[76, 4], dtype=torch.float32),
#  '405911-17-3': Data(x=[42, 77], edge_index=[2, 88], edge_attr=[88, 4], dtype=torch.float32),
#  '409345-29-5': Data(x=[24, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '41575-94-4': Data(x=[13, 77], edge_index=[2, 20], edge_attr=[20, 4], dtype=torch.float32),
#  '423735-93-7': Data(x=[22, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  '426219-18-3': Data(x=[23, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  '431979-47-4': Data(x=[30, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '438190-29-5': Data(x=[18, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  '439081-02-4': Data(x=[30, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  '444912-48-5': Data(x=[29, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '445430-58-0': Data(x=[19, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  '449811-92-1': Data(x=[28, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '451492-95-8': Data(x=[36, 77], edge_index=[2, 78], edge_attr=[78, 4], dtype=torch.float32),
#  '452342-67-5': Data(x=[32, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  '473382-39-7': Data(x=[28, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '476477-15-3': Data(x=[28, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '494772-86-0': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '4961-41-5': Data(x=[18, 77], edge_index=[2, 24], edge_attr=[24, 4], dtype=torch.float32),
#  '497839-62-0': Data(x=[33, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  '49843-98-3': Data(x=[17, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  '5-Aminolevulinic acid hydrochloride': Data(x=[10, 77], edge_index=[2, 16], edge_attr=[16, 4], dtype=torch.float32),
#  '5-Aminosalicylic acid': Data(x=[11, 77], edge_index=[2, 22], edge_attr=[22, 4], dtype=torch.float32),
#  "5-Fluoro-2'-deoxyuridine": Data(x=[17, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  '5-Fluorocytosine': Data(x=[9, 77], edge_index=[2, 18], edge_attr=[18, 4], dtype=torch.float32),
#  '5-Fluorouracil': Data(x=[9, 77], edge_index=[2, 18], edge_attr=[18, 4], dtype=torch.float32),
#  '5-azacytidine': Data(x=[17, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  '5-hydroxy-L-tryptophan': Data(x=[16, 77], edge_index=[2, 34], edge_attr=[34, 4], dtype=torch.float32),
#  '5-hydroxytryptophan': Data(x=[16, 77], edge_index=[2, 34], edge_attr=[34, 4], dtype=torch.float32),
#  '500579-04-4': Data(x=[32, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  '501919-59-1': Data(x=[25, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  '501925-31-1': Data(x=[21, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  '503468-95-9': Data(x=[30, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  '504433-23-2': Data(x=[21, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  '51-56-9': Data(x=[21, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  '54-62-6': Data(x=[32, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  '545380-34-5': Data(x=[27, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  '546141-08-6': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '547757-23-3': Data(x=[20, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  '55-86-7': Data(x=[9, 77], edge_index=[2, 14], edge_attr=[14, 4], dtype=torch.float32),
#  '55778-02-4': Data(x=[22, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  '56990-57-9': Data(x=[31, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  '57-22-7': Data(x=[60, 77], edge_index=[2, 136], edge_attr=[136, 4], dtype=torch.float32),
#  '57477-39-1': Data(x=[17, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  '58131-57-0': Data(x=[20, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  '59643-91-3': Data(x=[8, 77], edge_index=[2, 18], edge_attr=[18, 4], dtype=torch.float32),
#  '5987-82-6': Data(x=[23, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  '5Z-7-Oxozeaenol': Data(x=[26, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '6-Mercaptopurine': Data(x=[10, 77], edge_index=[2, 22], edge_attr=[22, 4], dtype=torch.float32),
#  '6-Thioguanine': Data(x=[11, 77], edge_index=[2, 24], edge_attr=[24, 4], dtype=torch.float32),
#  '6-aminohexanoic acid': Data(x=[9, 77], edge_index=[2, 16], edge_attr=[16, 4], dtype=torch.float32),
#  '602306-29-6': Data(x=[26, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  '607742-69-8': Data(x=[25, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  '61350-00-3': Data(x=[16, 77], edge_index=[2, 34], edge_attr=[34, 4], dtype=torch.float32),
#  '61618-27-7': Data(x=[21, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  '626222-24-0': Data(x=[26, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  '629664-81-9': Data(x=[32, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  '635318-11-5': Data(x=[15, 77], edge_index=[2, 32], edge_attr=[32, 4], dtype=torch.float32),
#  '6402-23-9': Data(x=[26, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  '6429-04-5': Data(x=[26, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '648450-29-7': Data(x=[18, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  '649756-01-4': Data(x=[27, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  '65666-07-1': Data(x=[35, 77], edge_index=[2, 78], edge_attr=[78, 4], dtype=torch.float32),
#  '65678-07-1': Data(x=[18, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  '666260-75-9': Data(x=[29, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '667463-62-9': Data(x=[22, 77], edge_index=[2, 50], edge_attr=[50, 4], dtype=torch.float32),
#  '67469-78-7': Data(x=[35, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  '681136-29-8': Data(x=[26, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  '6898-97-1': Data(x=[20, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  '690206-97-4': Data(x=[23, 77], edge_index=[2, 50], edge_attr=[50, 4], dtype=torch.float32),
#  '693228-63-6': Data(x=[26, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  '7-Aminocephalosporanic acid': Data(x=[18, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  '7-Ethyl-10-hydroxycamptothecin': Data(x=[29, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  '702675-74-9': Data(x=[34, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  '7081-53-0': Data(x=[30, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '711085-63-1': Data(x=[18, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  '71555-25-4': Data(x=[16, 77], edge_index=[2, 34], edge_attr=[34, 4], dtype=torch.float32),
#  '7218-04-4': Data(x=[10, 77], edge_index=[2, 18], edge_attr=[18, 4], dtype=torch.float32),
#  '722544-51-6': Data(x=[37, 77], edge_index=[2, 80], edge_attr=[80, 4], dtype=torch.float32),
#  '732302-99-7': Data(x=[33, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  '741713-40-6': Data(x=[30, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '761437-28-9': Data(x=[33, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  '761439-42-3': Data(x=[42, 77], edge_index=[2, 92], edge_attr=[92, 4], dtype=torch.float32),
#  '7728-73-6': Data(x=[28, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  '7803-88-5': Data(x=[21, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  '781661-94-7': Data(x=[28, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  '8-AZAGUANINE': Data(x=[11, 77], edge_index=[2, 24], edge_attr=[24, 4], dtype=torch.float32),
#  '8-Methyl-N-Vanillyl-6-Nonenamide': Data(x=[22, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  '80306-38-3': Data(x=[18, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  '803712-79-0': Data(x=[29, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '827022-32-2': Data(x=[34, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  '83-88-5': Data(x=[27, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  '841290-80-0': Data(x=[34, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  '844499-71-4': Data(x=[26, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  '850173-95-4': Data(x=[30, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '851723-84-7': Data(x=[26, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  '852475-26-4': Data(x=[23, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  '853910-02-8': Data(x=[33, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  '856243-80-6': Data(x=[24, 77], edge_index=[2, 50], edge_attr=[50, 4], dtype=torch.float32),
#  '865362-74-9': Data(x=[25, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  '869288-64-2': Data(x=[34, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  '873225-46-8': Data(x=[35, 77], edge_index=[2, 80], edge_attr=[80, 4], dtype=torch.float32),
#  '878739-06-1': Data(x=[34, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  '882257-11-6': Data(x=[20, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  '883050-24-6': Data(x=[22, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  '885060-08-2': Data(x=[29, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '885692-52-4': Data(x=[34, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  '887650-05-7': Data(x=[42, 77], edge_index=[2, 92], edge_attr=[92, 4], dtype=torch.float32),
#  '891494-63-6': Data(x=[23, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  '891494-64-7': Data(x=[23, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  '89565-68-4': Data(x=[21, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  '89778-26-7': Data(x=[29, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '9-BETA-D-XYLOFURANOSYL-ADENINE': Data(x=[19, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  '9-cis Acitretin': Data(x=[24, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  '900515-16-4': Data(x=[21, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  '905579-51-3': Data(x=[31, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  '905586-69-8': Data(x=[26, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  '906673-24-3': Data(x=[19, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  '908115-27-5': Data(x=[37, 77], edge_index=[2, 80], edge_attr=[80, 4], dtype=torch.float32),
#  '909910-43-6': Data(x=[31, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  '912545-86-9': Data(x=[34, 77], edge_index=[2, 76], edge_attr=[76, 4], dtype=torch.float32),
#  '913376-84-8': Data(x=[41, 77], edge_index=[2, 90], edge_attr=[90, 4], dtype=torch.float32),
#  '915019-65-7': Data(x=[36, 77], edge_index=[2, 82], edge_attr=[82, 4], dtype=torch.float32),
#  '915087-27-3': Data(x=[33, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  '915385-81-8 (free base)': Data(x=[27, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '920113-03-7': Data(x=[29, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  '925434-55-5': Data(x=[34, 77], edge_index=[2, 78], edge_attr=[78, 4], dtype=torch.float32),
#  '925705-73-3': Data(x=[19, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  '926319-75-7': Data(x=[31, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '928774-43-0': Data(x=[29, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  '934593-90-5': Data(x=[32, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  '936091-15-5': Data(x=[36, 77], edge_index=[2, 78], edge_attr=[78, 4], dtype=torch.float32),
#  '936091-56-4': Data(x=[36, 77], edge_index=[2, 78], edge_attr=[78, 4], dtype=torch.float32),
#  '937174-76-0': Data(x=[31, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  '939791-38-5': Data(x=[45, 77], edge_index=[2, 96], edge_attr=[96, 4], dtype=torch.float32),
#  '940929-33-9': Data(x=[38, 77], edge_index=[2, 80], edge_attr=[80, 4], dtype=torch.float32),
#  '944261-79-4': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  '94875-80-6': Data(x=[27, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  '951151-97-6': Data(x=[25, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  '955-24-8': Data(x=[17, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  '957054-30-7': Data(x=[35, 77], edge_index=[2, 80], edge_attr=[80, 4], dtype=torch.float32),
#  '959122-11-3': Data(x=[32, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  '96036-03-2': Data(x=[26, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  'A 438079': Data(x=[20, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  'A 839977': Data(x=[28, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  'A-443654': Data(x=[30, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  'A-674563': Data(x=[27, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  'A-770041': Data(x=[46, 77], edge_index=[2, 104], edge_attr=[104, 4], dtype=torch.float32),
#  'ABEXINOSTAT': Data(x=[29, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  'ABT-737': Data(x=[56, 77], edge_index=[2, 122], edge_attr=[122, 4], dtype=torch.float32),
#  'ABT-751': Data(x=[26, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  'AC-261066': Data(x=[24, 77], edge_index=[2, 50], edge_attr=[50, 4], dtype=torch.float32),
#  'AC1MDWZ9': Data(x=[20, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  'AC265347': Data(x=[20, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  'ACADESINE': Data(x=[18, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  'ACC1 BMS': Data(x=[23, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  'ACETYLCHOLINE CHLORIDE': Data(x=[11, 77], edge_index=[2, 18], edge_attr=[18, 4], dtype=torch.float32),
#  'ACHP': Data(x=[27, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  'ACIPIMOX': Data(x=[11, 77], edge_index=[2, 22], edge_attr=[22, 4], dtype=torch.float32),
#  'ADAPALENE': Data(x=[31, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  'ADEFOVIR DIPIVOXIL': Data(x=[34, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  'ADL5859': Data(x=[29, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  'ADM hydrochloride': Data(x=[40, 77], edge_index=[2, 86], edge_attr=[86, 4], dtype=torch.float32),
#  'ADX-47273': Data(x=[27, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  'AG-041R': Data(x=[40, 77], edge_index=[2, 86], edge_attr=[86, 4], dtype=torch.float32),
#  'AG-1478': Data(x=[22, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  'AG14361': Data(x=[24, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  'AGI-5198': Data(x=[34, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  'AGI-6780': Data(x=[32, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  'AIM-100': Data(x=[28, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  'AK-7': Data(x=[26, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  'ALLYLTHIOUREA': Data(x=[7, 77], edge_index=[2, 12], edge_attr=[12, 4], dtype=torch.float32),
#  'ALVERINE CITRATE': Data(x=[34, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  'AM251': Data(x=[30, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'AMD 473': Data(x=[11, 77], edge_index=[2, 14], edge_attr=[14, 4], dtype=torch.float32),
#  'AMG-208': Data(x=[29, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'AMG-25': Data(x=[30, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  'AMG-458': Data(x=[40, 77], edge_index=[2, 88], edge_attr=[88, 4], dtype=torch.float32),
#  'AMG-47a': Data(x=[39, 77], edge_index=[2, 86], edge_attr=[86, 4], dtype=torch.float32),
#  'AMG-51': Data(x=[46, 77], edge_index=[2, 102], edge_attr=[102, 4], dtype=torch.float32),
#  'AMG-517': Data(x=[30, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'AMG-900': Data(x=[37, 77], edge_index=[2, 84], edge_attr=[84, 4], dtype=torch.float32),
#  'AMG-Tie2-1': Data(x=[35, 77], edge_index=[2, 76], edge_attr=[76, 4], dtype=torch.float32),
#  'AMILORIDE': Data(x=[15, 77], edge_index=[2, 30], edge_attr=[30, 4], dtype=torch.float32),
#  'AMILORIDE HYDROCHLORIDE': Data(x=[16, 77], edge_index=[2, 30], edge_attr=[30, 4], dtype=torch.float32),
#  'AMPICILLIN SODIUM': Data(x=[25, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  'AMPICILLIN TRIHYDRATE': Data(x=[27, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  'ANAGRELIDE HYDROCHLORIDE': Data(x=[17, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  'ANISOTROPINE METHYLBROMIDE': Data(x=[21, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  'AP26113': Data(x=[36, 77], edge_index=[2, 78], edge_attr=[78, 4], dtype=torch.float32),
#  'APR-246': Data(x=[14, 77], edge_index=[2, 30], edge_attr=[30, 4], dtype=torch.float32),
#  'AR-42': Data(x=[23, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  'AR-A014418': Data(x=[21, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  'AR-C155858': Data(x=[32, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  'ARN-509': Data(x=[33, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  'ARTICAINE HYDROCHLORIDE': Data(x=[20, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  'AS-252424': Data(x=[21, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  'AS-604850': Data(x=[19, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  'AS601245': Data(x=[27, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  'ASCORBYL PALMITATE': Data(x=[29, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  'ASP3026': Data(x=[41, 77], edge_index=[2, 90], edge_attr=[90, 4], dtype=torch.float32),
#  'AST-1306': Data(x=[32, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  'AT-406': Data(x=[41, 77], edge_index=[2, 88], edge_attr=[88, 4], dtype=torch.float32),
#  'AT7519': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  'AT7867': Data(x=[24, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  'AT9283': Data(x=[28, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  'ATORVASTATIN CALCIUM': Data(x=[83, 77], edge_index=[2, 176], edge_attr=[176, 4], dtype=torch.float32),
#  'ATOVAQUONE': Data(x=[26, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  'ATROPINE': Data(x=[21, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  'AVL-292': Data(x=[31, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'AVN-944': Data(x=[35, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  'AZ-23': Data(x=[27, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  'AZ10606120': Data(x=[31, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  'AZ12419304': Data(x=[33, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  'AZ12799043': Data(x=[35, 77], edge_index=[2, 76], edge_attr=[76, 4], dtype=torch.float32),
#  'AZ13406193': Data(x=[24, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  'AZ13409007, AKTaz': Data(x=[29, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'AZ13453202': Data(x=[46, 77], edge_index=[2, 102], edge_attr=[102, 4], dtype=torch.float32),
#  'AZ191': Data(x=[32, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  'AZ20': Data(x=[29, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'AZD-26': Data(x=[26, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  'AZD-4877': Data(x=[36, 77], edge_index=[2, 78], edge_attr=[78, 4], dtype=torch.float32),
#  'AZD1080': Data(x=[25, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  'AZD1208': Data(x=[27, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  'AZD1480': Data(x=[24, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  'AZD1981': Data(x=[26, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  'AZD2014': Data(x=[34, 77], edge_index=[2, 76], edge_attr=[76, 4], dtype=torch.float32),
#  'AZD2461': Data(x=[29, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  'AZD2858': Data(x=[32, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  'AZD3463': Data(x=[32, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  'AZD3514': Data(x=[37, 77], edge_index=[2, 82], edge_attr=[82, 4], dtype=torch.float32),
#  'AZD4320': Data(x=[63, 77], edge_index=[2, 136], edge_attr=[136, 4], dtype=torch.float32),
#  'AZD4547': Data(x=[34, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  'AZD5363': Data(x=[30, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'AZD5582': Data(x=[74, 77], edge_index=[2, 162], edge_attr=[162, 4], dtype=torch.float32),
#  'AZD6482': Data(x=[30, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'AZD6738': Data(x=[29, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'AZD7545': Data(x=[31, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  'AZD7762': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  'AZD8055': Data(x=[34, 77], edge_index=[2, 76], edge_attr=[76, 4], dtype=torch.float32),
#  'AZD8186': Data(x=[33, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  'AZD8330': Data(x=[25, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  'AZELASTINE HYDROCHLORIDE': Data(x=[28, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  'AZILSARTAN MEDOXOMIL': Data(x=[42, 77], edge_index=[2, 94], edge_attr=[94, 4], dtype=torch.float32),
#  'AZLOCILLIN SODIUM': Data(x=[33, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  'Abiraterone': Data(x=[26, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  'Abiraterone acetate': Data(x=[29, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'Acebutolol hydrochloride': Data(x=[25, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  'Aceclidine hydrochloride': Data(x=[13, 77], edge_index=[2, 26], edge_attr=[26, 4], dtype=torch.float32),
#  'Acesulfame potassium': Data(x=[11, 77], edge_index=[2, 20], edge_attr=[20, 4], dtype=torch.float32),
#  'Acetovanillone': Data(x=[12, 77], edge_index=[2, 24], edge_attr=[24, 4], dtype=torch.float32),
#  'Acitazanolast': Data(x=[17, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  'Acitretin': Data(x=[24, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  'Aclidinium bromide': Data(x=[34, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  'Adenine hydrochloride': Data(x=[11, 77], edge_index=[2, 22], edge_attr=[22, 4], dtype=torch.float32),
#  'Adiphenine hydrochloride': Data(x=[24, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  'AdipoRon': Data(x=[32, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  'Adrenalone hydrochloride': Data(x=[14, 77], edge_index=[2, 26], edge_attr=[26, 4], dtype=torch.float32),
#  'Afatinib': Data(x=[34, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  'Agomelatine': Data(x=[18, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  'Akt inhibitor VIII': Data(x=[42, 77], edge_index=[2, 98], edge_attr=[98, 4], dtype=torch.float32),
#  'Akt-I-1,2': Data(x=[26, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  'Albendazole oxide': Data(x=[19, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  'Alectinib': Data(x=[36, 77], edge_index=[2, 82], edge_attr=[82, 4], dtype=torch.float32),
#  'Alfuzosin Hydrochloride': Data(x=[29, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  'Alibendol': Data(x=[18, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  'Alisertib': Data(x=[37, 77], edge_index=[2, 82], edge_attr=[82, 4], dtype=torch.float32),
#  'Aliskiren': Data(x=[39, 77], edge_index=[2, 78], edge_attr=[78, 4], dtype=torch.float32),
#  'Aliskiren hemifumarate': Data(x=[86, 77], edge_index=[2, 170], edge_attr=[170, 4], dtype=torch.float32),
#  'Alizarin': Data(x=[18, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  'Almotriptan': Data(x=[23, 77], edge_index=[2, 50], edge_attr=[50, 4], dtype=torch.float32),
#  'Almotriptan malate': Data(x=[32, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'Aloe-emodin': Data(x=[20, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  'Alogliptin': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  'Aloin B': Data(x=[30, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'Aloperine': Data(x=[17, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  'Alpelisib(BYL-719)': Data(x=[30, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  'Altrenogest': Data(x=[23, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  'Amantadine hydrochloride': Data(x=[12, 77], edge_index=[2, 26], edge_attr=[26, 4], dtype=torch.float32),
#  'Amastatin': Data(x=[33, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  'Ambrisentan': Data(x=[28, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  'Ambroxol hydrochloride': Data(x=[19, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  'Amiodarone hydrochloride': Data(x=[32, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'Amitriptyline hydrochloride': Data(x=[22, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  'Ammonium glycyrrhizate': Data(x=[59, 77], edge_index=[2, 128], edge_attr=[128, 4], dtype=torch.float32),
#  'Amonafide': Data(x=[21, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  'Amorolfine': Data(x=[23, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  'Amoxicillin sodium': Data(x=[26, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  'Amprolium hydrochloride': Data(x=[20, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  'Amuvatinib': Data(x=[32, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  'Anacetrapib': Data(x=[44, 77], edge_index=[2, 94], edge_attr=[94, 4], dtype=torch.float32),
#  'Andarine': Data(x=[31, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  'Andrographolide': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  'Antazoline hydrochloride': Data(x=[21, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  'Antibiotic AD 32': Data(x=[51, 77], edge_index=[2, 110], edge_attr=[110, 4], dtype=torch.float32),
#  'Antibiotic AY 22989': Data(x=[65, 77], edge_index=[2, 136], edge_attr=[136, 4], dtype=torch.float32),
#  'Antimycin A': Data(x=[39, 77], edge_index=[2, 80], edge_attr=[80, 4], dtype=torch.float32),
# ...
#  'CHLOROGENIC ACID': Data(x=[25, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  'CHOLINE CHLORIDE': Data(x=[8, 77], edge_index=[2, 12], edge_attr=[12, 4], dtype=torch.float32),
#  'CI-988': Data(x=[45, 77], edge_index=[2, 100], edge_attr=[100, 4], dtype=torch.float32),
#  'CICLOPIROX': Data(x=[15, 77], edge_index=[2, 32], edge_attr=[32, 4], dtype=torch.float32),
#  'CILAZAPRIL MONOHYDRATE': Data(x=[31, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  'CINCHONIDINE': Data(x=[22, 77], edge_index=[2, 50], edge_attr=[50, 4], dtype=torch.float32),
#  'CLEMASTINE FUMARATE': Data(x=[32, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'CLOBETASOL PROPIONATE': Data(x=[32, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  'CLONIDINE HYDROCHLORIDE': Data(x=[15, 77], edge_index=[2, 30], edge_attr=[30, 4], dtype=torch.float32),
#  'CLORSULON': Data(x=[20, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  'CNX-774': Data(x=[37, 77], edge_index=[2, 80], edge_attr=[80, 4], dtype=torch.float32),
#  'CORTISONE ACETATE': Data(x=[29, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  'CP-673451': Data(x=[31, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  'CP-724714': Data(x=[35, 77], edge_index=[2, 76], edge_attr=[76, 4], dtype=torch.float32),
#  'CP-91149': Data(x=[28, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  'CPG-52364': Data(x=[36, 77], edge_index=[2, 80], edge_attr=[80, 4], dtype=torch.float32),
#  'CPI-613': Data(x=[26, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  'CRTh2 antagonist 2': Data(x=[34, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  'CTEP': Data(x=[27, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  'CTK8E8456': Data(x=[39, 77], edge_index=[2, 86], edge_attr=[86, 4], dtype=torch.float32),
#  'CTK9A1709': Data(x=[40, 77], edge_index=[2, 86], edge_attr=[86, 4], dtype=torch.float32),
#  'CUDC-101': Data(x=[32, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  'CUDC-907': Data(x=[36, 77], edge_index=[2, 80], edge_attr=[80, 4], dtype=torch.float32),
#  'CVT-6883': Data(x=[32, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  'CX-5461': Data(x=[37, 77], edge_index=[2, 84], edge_attr=[84, 4], dtype=torch.float32),
#  'CYP3cide': Data(x=[34, 77], edge_index=[2, 78], edge_attr=[78, 4], dtype=torch.float32),
#  'CYPROHEPTADINE': Data(x=[22, 77], edge_index=[2, 50], edge_attr=[50, 4], dtype=torch.float32),
#  'CYPROTERONE ACETATE': Data(x=[29, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'CYROMAZINE': Data(x=[12, 77], edge_index=[2, 26], edge_attr=[26, 4], dtype=torch.float32),
#  'CYTARABINE HYDROCHLORIDE': Data(x=[18, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  'CYTISINE': Data(x=[14, 77], edge_index=[2, 32], edge_attr=[32, 4], dtype=torch.float32),
#  'CZC24832': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  'Cabozantinib': Data(x=[37, 77], edge_index=[2, 82], edge_attr=[82, 4], dtype=torch.float32),
#  'Caffeic acid phenethyl ester': Data(x=[21, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  'Caffeine citrate': Data(x=[27, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  'Calcifediol': Data(x=[29, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  'Calmidazolium': Data(x=[40, 77], edge_index=[2, 88], edge_attr=[88, 4], dtype=torch.float32),
#  'Camostat': Data(x=[29, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  'Camostat mesylate': Data(x=[34, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  'Canadine': Data(x=[25, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  'Canagliflozin': Data(x=[31, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  'Candesartan cilexetil': Data(x=[45, 77], edge_index=[2, 100], edge_attr=[100, 4], dtype=torch.float32),
#  'Canertinib': Data(x=[34, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  'Capecitabine (Xeloda)': Data(x=[25, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  'Carbenicillin disodium': Data(x=[28, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  'Carbimazole': Data(x=[12, 77], edge_index=[2, 24], edge_attr=[24, 4], dtype=torch.float32),
#  'Carboplatin Paclitaxel': Data(x=[75, 77], edge_index=[2, 156], edge_attr=[156, 4], dtype=torch.float32),
#  'Carboplatinum': Data(x=[13, 77], edge_index=[2, 20], edge_attr=[20, 4], dtype=torch.float32),
#  'Carboxyamidotriazole': Data(x=[27, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  'Cardamonin': Data(x=[20, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  'Cardiogenol C': Data(x=[19, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  'Carfilzomib': Data(x=[52, 77], edge_index=[2, 110], edge_attr=[110, 4], dtype=torch.float32),
#  'Caroverine': Data(x=[27, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  'Caspofungin acetate': Data(x=[85, 77], edge_index=[2, 172], edge_attr=[172, 4], dtype=torch.float32),
#  'Catharanthine': Data(x=[25, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  'Cathepsin inhibitor 1': Data(x=[28, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  'Cdk/Crk Inhibitor': Data(x=[32, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  'Cdk4/6 Inhibitor IV': Data(x=[34, 77], edge_index=[2, 76], edge_attr=[76, 4], dtype=torch.float32),
#  'Cediranib': Data(x=[33, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  'Cefoselis sulfate': Data(x=[40, 77], edge_index=[2, 84], edge_attr=[84, 4], dtype=torch.float32),
#  'Cefprozil monohydrate': Data(x=[28, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  'Ceftiofur': Data(x=[34, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  'Ceftiofur hydrochloride': Data(x=[35, 77], edge_index=[2, 74], edge_attr=[74, 4], dtype=torch.float32),
#  'Cephalomannine': Data(x=[60, 77], edge_index=[2, 130], edge_attr=[130, 4], dtype=torch.float32),
#  'Cetirizine dihydrochloride': Data(x=[29, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  'Cetrimonium bromide': Data(x=[21, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  'Chlorhexidine Base': Data(x=[34, 77], edge_index=[2, 70], edge_attr=[70, 4], dtype=torch.float32),
#  'Chloropyramine hydrochloride': Data(x=[21, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  'Chlorpheniramine maleate': Data(x=[27, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  'Chlorpromazine hydrochloride': Data(x=[22, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  'Chlorquinaldol': Data(x=[14, 77], edge_index=[2, 30], edge_attr=[30, 4], dtype=torch.float32),
#  'Chrysophanol': Data(x=[19, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  'Ciclopirox olamine': Data(x=[19, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  'Cidofovir': Data(x=[18, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  'Cilengitide': Data(x=[42, 77], edge_index=[2, 86], edge_attr=[86, 4], dtype=torch.float32),
#  'Ciliobrevin D': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  'Cilomilast': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  'Cinacalcet': Data(x=[26, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  'Cinacalcet hydrochloride': Data(x=[27, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  'Cinchophen': Data(x=[19, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  'Ciprofibrate': Data(x=[18, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  'Cisatracurium besylate': Data(x=[87, 77], edge_index=[2, 184], edge_attr=[184, 4], dtype=torch.float32),
#  'Cl-F-araA': Data(x=[20, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  'Cladribine': Data(x=[19, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  'Clevidipine': Data(x=[30, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  'Clevudine': Data(x=[18, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  'Climbazole': Data(x=[20, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  'Clindamycin hydrochloride': Data(x=[28, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  'Clindamycin palmitate HCl': Data(x=[45, 77], edge_index=[2, 90], edge_attr=[90, 4], dtype=torch.float32),
#  'Clofarabine': Data(x=[20, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  'Clomifene citrate': Data(x=[42, 77], edge_index=[2, 86], edge_attr=[86, 4], dtype=torch.float32),
#  'Clomipramine hydrochloride': Data(x=[23, 77], edge_index=[2, 48], edge_attr=[48, 4], dtype=torch.float32),
#  'Closantel': Data(x=[30, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  'Closantel sodium': Data(x=[31, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  'Cloxacillin sodium': Data(x=[31, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  'Co-V': Data(x=[19, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  'Cobicistat': Data(x=[54, 77], edge_index=[2, 116], edge_attr=[116, 4], dtype=torch.float32),
#  'Cobimetinib (R-enantiomer)': Data(x=[30, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'Coenzyme Q10': Data(x=[63, 77], edge_index=[2, 126], edge_attr=[126, 4], dtype=torch.float32),
#  'Conivaptan': Data(x=[38, 77], edge_index=[2, 86], edge_attr=[86, 4], dtype=torch.float32),
#  'Conivaptan hydrochloride': Data(x=[39, 77], edge_index=[2, 86], edge_attr=[86, 4], dtype=torch.float32),
#  'Copanlisib': Data(x=[35, 77], edge_index=[2, 78], edge_attr=[78, 4], dtype=torch.float32),
#  'Costunolide': Data(x=[17, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  'Cot inhibitor-2': Data(x=[37, 77], edge_index=[2, 82], edge_attr=[82, 4], dtype=torch.float32),
#  'Crenolanib': Data(x=[33, 77], edge_index=[2, 76], edge_attr=[76, 4], dtype=torch.float32),
#  'Crizotinib': Data(x=[30, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'Cryptotanshinone': Data(x=[22, 77], edge_index=[2, 50], edge_attr=[50, 4], dtype=torch.float32),
#  'Crystal violet': Data(x=[29, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  'Curcumol': Data(x=[17, 77], edge_index=[2, 38], edge_attr=[38, 4], dtype=torch.float32),
#  'Cutamesine': Data(x=[27, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  'Cyclamic acid': Data(x=[11, 77], edge_index=[2, 22], edge_attr=[22, 4], dtype=torch.float32),
#  'Cyclizine 2HCl': Data(x=[22, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  'Cyclocytidine hydrochloride': Data(x=[17, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  'Cyclovirobuxine D': Data(x=[29, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'Cyprodime': Data(x=[26, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  'Cysteamine hydrochloride': Data(x=[5, 77], edge_index=[2, 6], edge_attr=[6, 4], dtype=torch.float32),
#  'Cyt387': Data(x=[31, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  'D(+)-Glucose': Data(x=[12, 77], edge_index=[2, 22], edge_attr=[22, 4], dtype=torch.float32),
#  'D-106669': Data(x=[24, 77], edge_index=[2, 52], edge_attr=[52, 4], dtype=torch.float32),
#  'D-Penicillamine': Data(x=[9, 77], edge_index=[2, 16], edge_attr=[16, 4], dtype=torch.float32),
#  'D-Sorbitol': Data(x=[12, 77], edge_index=[2, 22], edge_attr=[22, 4], dtype=torch.float32),
#  'D-Xyl': Data(x=[10, 77], edge_index=[2, 20], edge_attr=[20, 4], dtype=torch.float32),
#  'D-cycloserine': Data(x=[7, 77], edge_index=[2, 14], edge_attr=[14, 4], dtype=torch.float32),
#  'D-mannitol': Data(x=[12, 77], edge_index=[2, 22], edge_attr=[22, 4], dtype=torch.float32),
#  'DANOPREVIR': Data(x=[51, 77], edge_index=[2, 112], edge_attr=[112, 4], dtype=torch.float32),
#  'DAPTOMYCIN': Data(x=[115, 77], edge_index=[2, 236], edge_attr=[236, 4], dtype=torch.float32),
#  'DASA-58': Data(x=[30, 77], edge_index=[2, 66], edge_attr=[66, 4], dtype=torch.float32),
#  'DBeQ': Data(x=[26, 77], edge_index=[2, 58], edge_attr=[58, 4], dtype=torch.float32),
#  'DECAMETHONIUM BROMIDE': Data(x=[20, 77], edge_index=[2, 34], edge_attr=[34, 4], dtype=torch.float32),
#  'DEFLAZACORT': Data(x=[32, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  'DESONIDE': Data(x=[30, 77], edge_index=[2, 68], edge_attr=[68, 4], dtype=torch.float32),
#  'DETOMIDINE HYDROCHLORIDE': Data(x=[15, 77], edge_index=[2, 30], edge_attr=[30, 4], dtype=torch.float32),
#  'DEXMEDETOMIDINE': Data(x=[15, 77], edge_index=[2, 32], edge_attr=[32, 4], dtype=torch.float32),
#  'DICLAZURIL': Data(x=[26, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  'DIFLOXACIN HYDROCHLORIDE': Data(x=[30, 77], edge_index=[2, 64], edge_attr=[64, 4], dtype=torch.float32),
#  'DIPERODON HYDROCHLORIDE': Data(x=[30, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  'DIPHEMANIL METHYLSULFATE': Data(x=[27, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  'DIPHENHYDRAMINE HYDROCHLORIDE': Data(x=[20, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  'DIVALPROEX SODIUM': Data(x=[21, 77], edge_index=[2, 36], edge_attr=[36, 4], dtype=torch.float32),
#  'DIZOCILPINE': Data(x=[17, 77], edge_index=[2, 40], edge_attr=[40, 4], dtype=torch.float32),
#  'DL-Carnitine hydrochloride': Data(x=[12, 77], edge_index=[2, 20], edge_attr=[20, 4], dtype=torch.float32),
#  'DMXAA': Data(x=[21, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  'DOXOFYLLINE': Data(x=[19, 77], edge_index=[2, 42], edge_attr=[42, 4], dtype=torch.float32),
#  'DSSTox_CID_16760': Data(x=[15, 77], edge_index=[2, 26], edge_attr=[26, 4], dtype=torch.float32),
#  'DSSTox_CID_20664': Data(x=[15, 77], edge_index=[2, 30], edge_attr=[30, 4], dtype=torch.float32),
#  'DSSTox_CID_28582': Data(x=[46, 77], edge_index=[2, 96], edge_attr=[96, 4], dtype=torch.float32),
#  'DU-21220': Data(x=[21, 77], edge_index=[2, 44], edge_attr=[44, 4], dtype=torch.float32),
#  'DULOXETINE HYDROCHLORIDE': Data(x=[22, 77], edge_index=[2, 46], edge_attr=[46, 4], dtype=torch.float32),
#  'Dabigatran': Data(x=[35, 77], edge_index=[2, 76], edge_attr=[76, 4], dtype=torch.float32),
#  'Dabigatran etexilate mesylate': Data(x=[46, 77], edge_index=[2, 98], edge_attr=[98, 4], dtype=torch.float32),
#  'Dabrafenib': Data(x=[35, 77], edge_index=[2, 76], edge_attr=[76, 4], dtype=torch.float32),
#  'Dacinostat': Data(x=[28, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  'Daclatasvir': Data(x=[54, 77], edge_index=[2, 118], edge_attr=[118, 4], dtype=torch.float32),
#  'Dacomitinib': Data(x=[33, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  'Dalcetrapib': Data(x=[27, 77], edge_index=[2, 56], edge_attr=[56, 4], dtype=torch.float32),
#  'Daminozide': Data(x=[11, 77], edge_index=[2, 20], edge_attr=[20, 4], dtype=torch.float32),
#  'Danusertib': Data(x=[35, 77], edge_index=[2, 78], edge_attr=[78, 4], dtype=torch.float32),
#  'Dapagliflozin': Data(x=[28, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  'Dapagliflozin C-2 Epimer': Data(x=[28, 77], edge_index=[2, 60], edge_attr=[60, 4], dtype=torch.float32),
#  'Dapivirine': Data(x=[25, 77], edge_index=[2, 54], edge_attr=[54, 4], dtype=torch.float32),
#  'Daporinad': Data(x=[29, 77], edge_index=[2, 62], edge_attr=[62, 4], dtype=torch.float32),
#  'Dapoxetine': Data(x=[23, 77], edge_index=[2, 50], edge_attr=[50, 4], dtype=torch.float32),
#  'Dapoxetine hydrochloride': Data(x=[24, 77], edge_index=[2, 50], edge_attr=[50, 4], dtype=torch.float32),
#  'Darifenacin hydrobromide': Data(x=[33, 77], edge_index=[2, 72], edge_attr=[72, 4], dtype=torch.float32),
#  ...}

# %%
np.save('./drug_feature_graph.npy', drug_dict)
